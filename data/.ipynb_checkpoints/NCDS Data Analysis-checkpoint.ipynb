# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Have a look at the two datasets

# %% [markdown]
# In this stage, we use some predictors from sweep0-3 and sweep5.

# %%
sweep5 = pd.read_csv("ncds_sweep5/tab/ncds5cmi.tab",delimiter="\t")
sweep5.head(10)
# Out:
# /Users/sophiasi/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (4,8,9,79,128,129,130,131,132,133,134,136,139,142,145,148,151,154,157,160,163,166,171,172,173,174,177,178,179,180,183,184,186,187,188,189,190,191,192,193,194,196,197,199,200,201,202,203,204,205,206,207,209,212,215,229,231,234,235,236,237,240,241,242,243,249,257,286,289,290,291,292,295,296,297,298,301,302,303,304,407,416,425,444,445,449,450,453,454,455,459,460,463,464,465,469,470,473,474,475,479,480,483,484,489,490,495,496,501,502,541,542,546,547,551,552,556,557,560,561,572,573,574,575,576,578,579,580,581,582,584,585,586,587,588,590,591,592,593,594,619,621,623,625,627,629,631,633,635,637,639,641,643,645,648,650,653,655,658,660,664,665,669,673,674,678,682,683,687,691,692,696,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,737,738,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,760,766,806,808,810,812,825,827,830,831,832,833,834,835,836,837,838,839,840,841,842,846,848,849,850,851,852,855,860,878,879,915,928,929,933,934,938,940,942,943,945,946,953,954,955,958,959,960,964,965,966,967,969,971,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1053,1088,1124,1127,1130,1133,1135,1136,1139,1142,1145,1148,1160,1163,1166,1177,1180,1184,1190,1193,1203,1204,1206,1240,1257,1283,1296,1299,1300,1301,1302,1303,1304,1307,1308,1309,1310,1311,1312,1313,1314,1318,1320,1325,1328,1329,1330,1331,1332,1333,1335,1337,1339,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1362,1364,1365,1368,1370,1383,1394,1400,1402,1412,1422,1432,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1474,1484,1486,1487,1488,1489,1490,1491,1492,1493,1494,1495,1496,1497,1498,1499,1500,1501,1502,1503,1504,1505,1506,1507,1508,1509,1510,1512,1513,1517,1518,1521,1522,1523,1527,1528,1531,1532,1533,1537,1538,1541,1542,1543,1547,1548,1551,1552,1557,1558,1563,1564,1569,1570,1598,1609,1610,1614,1615,1619,1620,1624,1625,1628,1629,1630,1631,1632,1634,1635,1636,1637,1638,1640,1641,1642,1643,1644,1646,1647,1648,1649,1650,1654,1679,1685,1691,1697,1699,1704,1709,1714,1725,1734,1743,1752,3168,3170,3171,3172,3175,3176,3177,3178,3179,3180,3181,3182,3188) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     ncdsid  person  n622_5  n5region n5gor  resp5cmi  resp5wyt  resp5cl  \
# 0  N10001N       1       2         6     9         1         1        1
# 1  N10002P       1       1         5     8         1         1        1
# 2  N10004R       1       2         1     2         1         1        1
# 3  N10007U       1       2         6     9         1         1        1
# 4  N10009W       1       1         5     7         1         1        1
# 5  N10011Q       1       1         7     5         1         1        1
# 6  N10012R       1       1         6     9         1         1        1
# 7  N10013S       1       1         3     4         1         1        1
# 8  N10015U       1       1         1     1         1         0        0
# 9  N10016V       1       2         4     6         1         1        1
#
#   n500518 n500520   ...    child marchild hqual33 hqual23 verbal  \
# 0       0       2   ...        1        2       2       2    3.5
# 1       0       1   ...        2        5       4       4      4
# 2       0       5   ...        1        2       2       2      4
# 3       0       1   ...        2        6       3       3      3
# 4       0       1   ...        2        7       2      -1      4
# 5       0       1   ...        1        3       3       3    3.5
# 6       0       3   ...        1        1       4       0    3.5
# 7       0       1   ...        1        1       1       1    3.5
# 8       0       1   ...        1        1       1       1
# 9       0       2   ...        1        2       1       1    3.5
#
#            constrct keyboard            caring organise tenure91
# 0                 3        3  2.66666666666667      3.4        2
# 1                 4        4  3.66666666666667      3.8        2
# 2  3.33333333333333      1.5  3.33333333333333      3.4        3
# 3                 3      3.5                 3      2.8        2
# 4                 4        3  3.66666666666667      2.2       99
# 5  3.33333333333333        4  3.33333333333333      3.4        3
# 6                 4        1  3.33333333333333                 4
# 7  3.33333333333333        4                 4      3.6        2
# 8                                                              2
# 9  3.33333333333333        3  3.33333333333333      3.4        2
#
# [10 rows x 3189 columns]

# %%
sweep5.shape
# Out:
# (11469, 3189)

# %%
sweep0_3 = pd.read_csv("ncds_sweep0-3/tab/ncds0123.tab",delimiter="\t")
sweep0_3.head(10)
# Out:
# /Users/sophiasi/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (1,2,3,4,5,1756,1757,1758,1759,1760,1761,1762,1763,1764) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     ncdsid n622 n0region n1region n2region n3region n553 n545 n520 n490  \
# 0  N10001N    2        9        9        9        9   23    4    2   12
# 1  N10002P    1        9        8        8        8   34    4    5    1
# 2  N10003Q    1        4        4        4        4   34    4   10    1
# 3  N10004R    2        1        1        1        1   26    4   11    1
# 4  N10005S    2       10       10       10       10   25    4    1    3
# 5  N10006T    1        7        4        7        7   23    4    9    1
# 6  N10007U    2       -2       -1       -1        2
# 7  N10008V    1       10       -1       10       10   21    4   10    3
# 8  N10009W    1       -2        7        7       -1
# 9  N10010P    2        7        7        7        7   26    4    1    1
#
#          ...        n1849            dvht07            dvht11  \
# 0        ...           -1  1.21899986267032  1.47299957275415
# 1        ...           -1  1.34599971771224                -1
# 2        ...           -1  1.32099914550831  1.49899959564243
# 3        ...           -1  1.29499912262003  1.51099967956562
# 4        ...           -1  1.34599971771224                -1
# 5        ...               1.21899986267032  1.40999984741198
# 6        ...           -1                -1                -1
# 7        ...           -1                -1  1.26999950408932
# 8        ...               1.19399929046639  1.37799930572474
# 9        ...           -1  1.26999950408932  1.57499980926536
#
#              dvht16           dvrwt07           dvrwt11           dvrwt16  \
# 0  1.59999942779607  110.347991943347  98.1929931640604  105.055999755876
# 1                -1   90.865997314449                -1                -1
# 2  1.87999916076665  87.9599914550983  96.4049987792867   89.382995605487
# 3  1.62999916076665   105.16198730471  111.588989257796  132.054992675766
# 4                -1  129.382995605487                -1                -1
# 5                -1  96.2529907226337  94.2619934081847                -1
# 6                -1                -1                -1                -1
# 7  1.59999942779607                -1  104.393997192364  91.8689880371285
# 8                -1                -1  82.9279937743942                -1
# 9                -1                -1  118.603988647462                -1
#
#              dvwt07            dvwt11            dvwt16
# 0  25.8549957275385  37.6489868164152  56.0199890136717
# 1  26.3089904785155                -1                -1
# 2  24.4939880371087  38.1019897460905  66.6799926757659
# 3   28.122985839843  45.8139953613169  72.7999877929584
# 4  37.6489868164152                -1                -1
# 5  22.6799926757811  31.7519989013717                -1
# 6                -1                -1                -1
# 7                -1   26.761993408203  45.8099975585734
# 8                -1  26.3089904785155                -1
# 9                -1  54.4319915771376                -1
#
# [10 rows x 1765 columns]

# %%
sweep0_3.shape
# Out:
# (18558, 1765)

# %% [markdown]
# # Sweep 0_3 wrangling

# %% [markdown]
# Test a method to filter out the variables.

# %%
a = pd.DataFrame({"1P abc": [1,2,3], "1PM abc":[4,5,6]})
a
# Out:
#    1P abc  1PM abc
# 0       1        4
# 1       2        5
# 2       3        6

# %%
#check whether the variable name contains 1P, if not, drop the column
def drop_column(df, names):
    
    columns = df.columns.values
    for column in columns:
        if column.split()[0] in names:
            continue
        else:
            df.drop(column,1,inplace = True)  
    return df

drop_column(a,["1PM"])
# Out:
#    1PM abc
# 0        4
# 1        5
# 2        6

# %% [markdown]
# # Sweep 5 wrangling

# %% [markdown]
# In the following steps, I will filter out the health variables from sweep 5

# %%
var = pd.read_csv("ncds_sweep5/tab/health_var.txt", delimiter="\t",names=["label","others"])
var.head()
# Out:
#      label                                             others
# 0  N504147   CMI:83 F34 Any accident/assault since March 1981
# 1  N504148  CMI:83 F35 No. of accidents/assaults since Mar...
# 2  N504150      CMI:83 F36b) ACCIDENT/ASSAULT 1: Age occurred
# 3  N504152     CMI:83 F36c) ACCIDENT/ASSAULT 1: Incident type
# 4  N504153  CMI:83 F36d) ACCIDENT/ASSAULT 1: Admitted/outp...

# %%
#get list of health variables and predictors
var_health = [x.lower() for x in var["label"].values]
var_health.insert(0, "ncdsid")
print var_health[:3]
# Out:
# ['ncdsid', 'n504147', 'n504148']

# %% [markdown]
# Nice!! Then I can get a new dataframe only with these variables. For example:

# %%
sweep5[var_health].head()
# Out:
#     ncdsid n504147 n504148 n504150 n504152 n504153 n504154 n504156 n504157  \
# 0  N10001N       2
# 1  N10002P       2
# 2  N10004R       2
# 3  N10007U       2
# 4  N10009W       2
#
#   n504158   ...   n504475 n504476 n504513 n504514 n504515 n504516 n504517  \
# 0           ...                         1       2
# 1           ...                         1       2
# 2           ...                         1       2
# 3           ...                         1       2
# 4           ...                         1       2
#
#   n504518 n504519 n504520
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 400 columns]

# %% [markdown]
# # Merge them and set x and y

# %% [markdown]
# Now we can work on the whole dataset! Merge sweep 0-3 and sweep 5!

# %%
def get_labels(path,flag):

    # open explain file
    explain = open(path, 'r')

    # read the whole file as a single giant string
    explain_text = explain.read()

    # locate variable target string in the whole file
    target_string_var = 'Variable label ='
    target_loc_var = [m.end() for m in re.finditer(target_string_var, explain_text)]
    var_name_list = []
    # locate type target string in the whole file
    target_string_type = 'the SPSS measurement level is'
    target_loc_type = [m.end() for m in re.finditer(target_string_type, explain_text)]
    type_list = ["Categorical" for i in target_loc_var]

    #Find Numeric or Categorical
    for index, loc in enumerate(target_loc_type):
        # get feature character
        char = explain_text[loc+10]
        if char == "S" or char == "s":
            # it is SPSS data type ORDINAL or NOMINAL
            # it is categorical data
            type_list[index] = "Numeric"

            
    #Find variable label
    if flag == 0:
        for loc in target_loc_var:
            start_point = loc+11
            end_point = explain_text.find('\\\n', loc)
            var_name_list.append(explain_text[start_point:end_point])
    elif flag ==1:
        for loc in target_loc_var:
            start_point = loc+8
            end_point = explain_text.find('\par', loc)
            var_name_list.append(explain_text[start_point:end_point])
        
    explain.close()   
    return var_name_list, type_list

# %%
# file path of explain file
sweep5_path = 'ncds_sweep5/mrdoc/allissue/ncds5cmi_ukda_data_dictionary.rtf'
sweep0_3_path = 'ncds_sweep0-3/mrdoc/allissue/ncds0123_ukda_data_dictionary.rtf'
sweep0_3_labels, sweep0_3_type = get_labels(sweep0_3_path,1)
sweep5_labels, sweep5_type  = get_labels(sweep5_path,0)
print len(sweep0_3_labels), len(sweep5_labels)
# Out:
# 1765 3189

# %%
print len(sweep5_type), len(sweep0_3_type)
# Out:
# 3189 1765

# %% [markdown]
# Finally! We have everything we need to merge the two datasets!

# %%
#filter sweep0-3
sweep0_3.columns = sweep0_3_labels
sweep0_3.head()
# Out:
#   ncdsid serial number 0-3D Sex of child Region at PMS (1958) - Birth  \
# 0              N10001N                 2                            9
# 1              N10002P                 1                            9
# 2              N10003Q                 1                            4
# 3              N10004R                 2                            1
# 4              N10005S                 2                           10
#
#   Region at NCDS1 (1965) - 7 years Region at NCDS2 (1969) - 11 years  \
# 0                                9                                 9
# 1                                8                                 8
# 2                                4                                 4
# 3                                1                                 1
# 4                               10                                10
#
#   Region at NCDS3 (1974) - 16 years 0 Mother's age last birthday,in years  \
# 0                                 9                                    23
# 1                                 8                                    34
# 2                                 4                                    34
# 3                                 1                                    26
# 4                                10                                    25
#
#   0 Mother's present marital status 0 Interval between marriage & 1st birth  \
# 0                                 4                                       2
# 1                                 4                                       5
# 2                                 4                                      10
# 3                                 4                                      11
# 4                                 4                                       1
#
#   0 Socio-economic group mother's husband (GRO 1951)  \
# 0                                                 12
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#               ...              3D Losses at NCDS3  \
# 0             ...                              -1
# 1             ...                              -1
# 2             ...                              -1
# 3             ...                              -1
# 4             ...                              -1
#
#   1D Height in metres at 7 years 2D Height in metres at 11 years  \
# 0               1.21899986267032                1.47299957275415
# 1               1.34599971771224                              -1
# 2               1.32099914550831                1.49899959564243
# 3               1.29499912262003                1.51099967956562
# 4               1.34599971771224                              -1
#
#   3D Height in metres at 16 years 1D Relative weight at 7 years  \
# 0                1.59999942779607              110.347991943347
# 1                              -1               90.865997314449
# 2                1.87999916076665              87.9599914550983
# 3                1.62999916076665               105.16198730471
# 4                              -1              129.382995605487
#
#   2D Relative weight at 11 years 3D Relative weight at 16 years  \
# 0               98.1929931640604               105.055999755876
# 1                             -1                             -1
# 2               96.4049987792867                89.382995605487
# 3               111.588989257796               132.054992675766
# 4                             -1                             -1
#
#   1D Weight in Kg. at 7 years 2D Weight in Kg. at 11 years  \
# 0            25.8549957275385             37.6489868164152
# 1            26.3089904785155                           -1
# 2            24.4939880371087             38.1019897460905
# 3             28.122985839843             45.8139953613169
# 4            37.6489868164152                           -1
#
#   3D Weight in Kg. at 16 years
# 0             56.0199890136717
# 1                           -1
# 2             66.6799926757659
# 3             72.7999877929584
# 4                           -1
#
# [5 rows x 1765 columns]

# %%
sweep0_3_filtered = drop_column(sweep0_3, ["ncdsid","1P","1PD","1M","1D","2M","2P","3P","3M"])
sweep0_3_filtered.head()
# Out:
#   ncdsid serial number 1P Child 8 years-old at NCDS1 Parental  \
# 0              N10001N                                     -1
# 1              N10002P                                     -1
# 2              N10003Q                                     -1
# 3              N10004R                                     -1
# 4              N10005S                                     -1
#
#   1P Family moves since child's birth 1P Moves out of local area  \
# 0                                   1                          3
# 1                                   3                          2
# 2                                   0                          1
# 3                                   3                          3
# 4                                   2                          3
#
#   1P Informant's relationship to child 1P No. kids undr 21 hhld,inc liv away  \
# 0                                    1                                     3
# 1                                    1                                     2
# 2                                    1                                     8
# 3                                    1                                     2
# 4                                    1                                     2
#
#   1P Number of people in the household 1P Child's posn hhld ,inc those away  \
# 0                                    5                                    1
# 1                                    4                                    2
# 2                                    8                                    7
# 3                                    4                                    2
# 4                                    4                                    2
#
#   1P Relationship person acting as mother  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3                                       2
# 4                                       2
#
#   1P Relationship person acting as father             ...              \
# 0                                       2             ...
# 1                                       2             ...
# 2                                       2             ...
# 3                                       2             ...
# 4                                       2             ...
#
#   3M R ear-hearing loss at 8000 CPS x 5dB  \
# 0                                       0
# 1                                      -1
# 2                                      -1
# 3                                      20
# 4                                      -1
#
#   3M L ear-hearing loss at 250 CPS x 5dB  \
# 0                                      0
# 1                                     -1
# 2                                     -1
# 3                                     20
# 4                                     -1
#
#   3M L ear-hearing loss at 500 CPS x 5dB  \
# 0                                      0
# 1                                     -1
# 2                                     -1
# 3                                     20
# 4                                     -1
#
#   3M L ear-hearing loss at 1000 CPS x 5dB  \
# 0                                       0
# 1                                      -1
# 2                                      -1
# 3                                      20
# 4                                      -1
#
#   3M L ear-hearing loss at 2000 CPS x 5dB  \
# 0                                       0
# 1                                      -1
# 2                                      -1
# 3                                      20
# 4                                      -1
#
#   3M L ear-hearing loss at 4000 CPS x 5dB  \
# 0                                       0
# 1                                      -1
# 2                                      -1
# 3                                      20
# 4                                      -1
#
#   3M L ear-hearing loss at 8000 CPS x 5dB 1D Height in metres at 7 years  \
# 0                                       0               1.21899986267032
# 1                                      -1               1.34599971771224
# 2                                      -1               1.32099914550831
# 3                                      20               1.29499912262003
# 4                                      -1               1.34599971771224
#
#   1D Relative weight at 7 years 1D Weight in Kg. at 7 years
# 0              110.347991943347            25.8549957275385
# 1               90.865997314449            26.3089904785155
# 2              87.9599914550983            24.4939880371087
# 3               105.16198730471             28.122985839843
# 4              129.382995605487            37.6489868164152
#
# [5 rows x 1077 columns]

# %%
#filter sweep5
sweep5.loc[-2] = sweep5_labels # adding a row
sweep5.loc[-1] = sweep5_type
sweep5.index = sweep5.index + 2  # shifting index
sweep5 = sweep5.sort_index()
print sweep5.shape
sweep5.head()
# Out:
# (11471, 3189)
#                  ncdsid         person                n622_5  \
# 0  ncdsid serial number  PERSON NUMBER  Sex of Cohort Member
# 1           Categorical    Categorical               Numeric
# 2               N10001N              1                     2
# 3               N10002P              1                     1
# 4               N10004R              1                     2
#
#                    n5region                           n5gor  \
# 0  Standard region at NCDS5  NCDS5 Government Office Region
# 1                   Numeric                         Numeric
# 2                         6                               9
# 3                         5                               8
# 4                         1                               2
#
#                                resp5cmi  \
# 0  Responded to Cohort Member Interview
# 1                               Numeric
# 2                                     1
# 3                                     1
# 4                                     1
#
#                                        resp5wyt  \
# 0  Responded to What Do You Think Questionnaire
# 1                                       Numeric
# 2                                             1
# 3                                             1
# 4                                             1
#
#                                            resp5cl                   n500518  \
# 0  Responded to Your Life Since 1974 Questionnaire  Time of Interview (mins)
# 1                                      Categorical               Categorical
# 2                                                1                         0
# 3                                                1                         0
# 4                                                1                         0
#
#                                      n500520            ...              \
# 0  CMI:2,A1a) Current main economic activity            ...
# 1                                Categorical            ...
# 2                                          2            ...
# 3                                          1            ...
# 4                                          5            ...
#
#                                  child                          marchild  \
# 0  DV:Does respondent have child(ren)?  DV:Sex, Partnership and Children
# 1                          Categorical                       Categorical
# 2                                    1                                 2
# 3                                    2                                 5
# 4                                    1                                 2
#
#                             hqual33                           hqual23  \
# 0  DV:Highest qual gained at age 33  DV:Highest qual gained at age 23
# 1                       Categorical                       Categorical
# 2                                 2                                 2
# 3                                 4                                 4
# 4                                 2                                 2
#
#                            verbal                              constrct  \
# 0  DV:Possession of Verbal Skills  DV:Possession of Construction Skills
# 1                     Categorical                           Categorical
# 2                             3.5                                     3
# 3                               4                                     4
# 4                               4                      3.33333333333333
#
#                            keyboard                          caring  \
# 0  DV:Possession of Keyboard Skills  DV:Possession of Caring Skills
# 1                       Categorical                     Categorical
# 2                                 3                2.66666666666667
# 3                                 4                3.66666666666667
# 4                               1.5                3.33333333333333
#
#                                  organise                   tenure91
# 0  DV:Possession of Organisational Skills  DV:Housing tenure in 1991
# 1                             Categorical                Categorical
# 2                                     3.4                          2
# 3                                     3.8                          2
# 4                                     3.4                          3
#
# [5 rows x 3189 columns]

# %%
sweep5_filtered = sweep5[var_health]
sweep5_filtered.head()
# Out:
#                  ncdsid                                           n504147  \
# 0  ncdsid serial number  CMI:83 F34 Any accident/assault since March 1981
# 1           Categorical                                       Categorical
# 2               N10001N                                                 2
# 3               N10002P                                                 2
# 4               N10004R                                                 2
#
#                                              n504148  \
# 0  CMI:83 F35 No. of accidents/assaults since Mar...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                          n504150  \
# 0  CMI:83 F36b) ACCIDENT/ASSAULT 1: Age occurred
# 1                                    Categorical
# 2
# 3
# 4
#
#                                           n504152  \
# 0  CMI:83 F36c) ACCIDENT/ASSAULT 1: Incident type
# 1                                     Categorical
# 2
# 3
# 4
#
#                                              n504153  \
# 0  CMI:83 F36d) ACCIDENT/ASSAULT 1: Admitted/outp...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                          n504154  \
# 0  CMI:83 F36b) ACCIDENT/ASSAULT 2: Age occurred
# 1                                    Categorical
# 2
# 3
# 4
#
#                                           n504156  \
# 0  CMI:83 F36c) ACCIDENT/ASSAULT 2: Incident type
# 1                                     Categorical
# 2
# 3
# 4
#
#                                              n504157  \
# 0  CMI:83 F36d) ACCIDENT/ASSAULT 2: Admitted/outp...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                          n504158  \
# 0  CMI:83 F36b) ACCIDENT/ASSAULT 3: Age occurred
# 1                                    Categorical
# 2
# 3
# 4
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                             n504475  \
# 0  CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #5
# 1                                       Categorical
# 2
# 3
# 4
#
#                                             n504476  \
# 0  CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #6
# 1                                       Categorical
# 2
# 3
# 4
#
#                                          n504513  \
# 0  CMI:95 F75a) CHECK: F64 - Has driving licence
# 1                                    Categorical
# 2                                              1
# 3                                              1
# 4                                              1
#
#                                              n504514  \
# 0  CMI:95 F75b) Ever been convicted of traffic of...
# 1                                        Categorical
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#                                              n504515  \
# 0  CMI:95 F75c) Additional traffic offence convic...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                              n504516  \
# 0  CMI:95 F75c) Additional traffic offence convic...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                              n504517  \
# 0  CMI:95 F75c) Additional traffic offence convic...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                              n504518  \
# 0  CMI:95 F75c) Additional traffic offence convic...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                              n504519  \
# 0  CMI:95 F75c) Additional traffic offence convic...
# 1                                        Categorical
# 2
# 3
# 4
#
#                                              n504520
# 0  CMI:95 F75c) Additional traffic offence convic...
# 1                                        Categorical
# 2
# 3
# 4
#
# [5 rows x 400 columns]

# %%
sweep5_filtered = sweep5_filtered.rename(columns = sweep5_filtered.iloc[0])
sweep5_filtered = sweep5_filtered[1:]
print sweep5_filtered.shape
sweep5_filtered.head()
# Out:
# (11470, 400)
#   ncdsid serial number CMI:83 F34 Any accident/assault since March 1981  \
# 1          Categorical                                      Categorical
# 2              N10001N                                                2
# 3              N10002P                                                2
# 4              N10004R                                                2
# 5              N10007U                                                2
#
#   CMI:83 F35 No. of accidents/assaults since March 1981  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36b) ACCIDENT/ASSAULT 1: Age occurred  \
# 1                                   Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36c) ACCIDENT/ASSAULT 1: Incident type  \
# 1                                    Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36d) ACCIDENT/ASSAULT 1: Admitted/outpatient  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36b) ACCIDENT/ASSAULT 2: Age occurred  \
# 1                                   Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36c) ACCIDENT/ASSAULT 2: Incident type  \
# 1                                    Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36d) ACCIDENT/ASSAULT 2: Admitted/outpatient  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:83 F36b) ACCIDENT/ASSAULT 3: Age occurred  \
# 1                                   Categorical
# 2
# 3
# 4
# 5
#
#                            ...                           \
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
# 5                          ...
#
#   CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #5  \
# 1                                      Categorical
# 2
# 3
# 4
# 5
#
#   CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #6  \
# 1                                      Categorical
# 2
# 3
# 4
# 5
#
#   CMI:95 F75a) CHECK: F64 - Has driving licence  \
# 1                                   Categorical
# 2                                             1
# 3                                             1
# 4                                             1
# 5                                             1
#
#   CMI:95 F75b) Ever been convicted of traffic offence (excl F73-74)  \
# 1                                        Categorical
# 2                                                  2
# 3                                                  2
# 4                                                  2
# 5                                                  2
#
#   CMI:95 F75c) Additional traffic offence conviction #1  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:95 F75c) Additional traffic offence conviction #2  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:95 F75c) Additional traffic offence conviction #3  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:95 F75c) Additional traffic offence conviction #4  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:95 F75c) Additional traffic offence conviction #5  \
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
#   CMI:95 F75c) Additional traffic offence conviction #6
# 1                                        Categorical
# 2
# 3
# 4
# 5
#
# [5 rows x 400 columns]

# %% [markdown]
# Merge them!!!

# %%
merged = pd.merge(sweep0_3_filtered,sweep5_filtered,on = "ncdsid serial number")
print merged.shape
merged.head()
# Out:
# (11469, 1476)
#   ncdsid serial number 1P Child 8 years-old at NCDS1 Parental  \
# 0              N10001N                                     -1
# 1              N10002P                                     -1
# 2              N10004R                                     -1
# 3              N10007U
# 4              N10009W                                     -1
#
#   1P Family moves since child's birth 1P Moves out of local area  \
# 0                                   1                          3
# 1                                   3                          2
# 2                                   3                          3
# 3
# 4                                  12                          2
#
#   1P Informant's relationship to child 1P No. kids undr 21 hhld,inc liv away  \
# 0                                    1                                     3
# 1                                    1                                     2
# 2                                    1                                     2
# 3
# 4                                    2                                     2
#
#   1P Number of people in the household 1P Child's posn hhld ,inc those away  \
# 0                                    5                                    1
# 1                                    4                                    2
# 2                                    4                                    2
# 3
# 4                                    4                                    1
#
#   1P Relationship person acting as mother  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3
# 4                                       2
#
#   1P Relationship person acting as father  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3
# 4                                       2
#
#                            ...                           \
# 0                          ...
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
#
#   CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #5  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #6  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75a) CHECK: F64 - Has driving licence  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
#   CMI:95 F75b) Ever been convicted of traffic offence (excl F73-74)  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#   CMI:95 F75c) Additional traffic offence conviction #1  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #2  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #3  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #4  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #5  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #6
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 1476 columns]

# %% [markdown]
# # Time to do something on the merged data!!

# %%
a = pd.DataFrame({"index":[1,2,"3.5",4,5,6,7],"a":[2,2,3,4,5,6,7]})
a["index"] =  pd.to_numeric(a.iloc[:,1],errors='coerce')
a
# Out:
#    a  index
# 0  2    1.0
# 1  2    2.0
# 2  3    3.5
# 3  4    4.0
# 4  5    5.0
# 5  6    6.0
# 6  7    7.0

# %%
merged.drop("ncdsid serial number",1,inplace = True) 
print merged.shape
merged.head()
# Out:
# (11469, 1475)
#   1P Child 8 years-old at NCDS1 Parental 1P Family moves since child's birth  \
# 0                                     -1                                   1
# 1                                     -1                                   3
# 2                                     -1                                   3
# 3
# 4                                     -1                                  12
#
#   1P Moves out of local area 1P Informant's relationship to child  \
# 0                          3                                    1
# 1                          2                                    1
# 2                          3                                    1
# 3
# 4                          2                                    2
#
#   1P No. kids undr 21 hhld,inc liv away 1P Number of people in the household  \
# 0                                     3                                    5
# 1                                     2                                    4
# 2                                     2                                    4
# 3
# 4                                     2                                    4
#
#   1P Child's posn hhld ,inc those away  \
# 0                                    1
# 1                                    2
# 2                                    2
# 3
# 4                                    1
#
#   1P Relationship person acting as mother  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3
# 4                                       2
#
#   1P Relationship person acting as father  \
# 0                                       2
# 1                                       2
# 2                                       2
# 3
# 4                                       2
#
#   1PD Parental sit of illegitimate kids  \
# 0                                    -1
# 1                                    -1
# 2                                    -1
# 3
# 4                                    -1
#
#                            ...                           \
# 0                          ...
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
#
#   CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #5  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:94 F74d) ROAD TRAFFIC ACCIDENT 4: Offence #6  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75a) CHECK: F64 - Has driving licence  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             1
# 4                                             1
#
#   CMI:95 F75b) Ever been convicted of traffic offence (excl F73-74)  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#   CMI:95 F75c) Additional traffic offence conviction #1  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #2  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #3  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #4  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #5  \
# 0
# 1
# 2
# 3
# 4
#
#   CMI:95 F75c) Additional traffic offence conviction #6
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 1475 columns]

# %%
#convert all the predictors to numeric
def to_numeric(df):
    for index,column in enumerate(df.columns):
        temp = pd.to_numeric(df.iloc[:,index],errors='coerce')
        temp[temp < 0] ='nan'
        df[column] = temp
    return df

merged = to_numeric(merged)
merged["CMI:75 F3a) Epilepsy: Ever suffered"].unique()
# Out:
# array([  3.,   1.,  nan,   2.])

# %% [markdown]
# # Cleaned data

# %% [markdown]
# ### 1. The next step is to maybe dummify the categorical predictors. May be check df[column].unique()
#
# - if >15 (I have seen the discriptions and find this general rule, but there are exceptions, you are free to change the threshold), numeric; if < 15, dummify.
# - After dummifing, you may find some values are negtive, e.g.:

# %% [markdown]
# >Pos. = 68	Variable = n97	Variable label = 1P Moves out of local area
#
# >This variable is  numeric, the SPSS measurement level is ORDINAL
#
# >SPSS user missing values = -1.0 thru None
#
# 	>Value label information for n97
#
# 	>Value = 1.0	Label = DK,Inapplicable
#
# 	>Value = 2.0	Label = Yes
#
# 	>Value = 3.0	Label = No
#
# 	>**Value = -1.0  Label = NA**
#
# **Notice the last line, values = -1, in the dataset, I have already converted all the negtive values to nan.**
# May be delete nan columns after dummifying.

# %% [markdown]
# ### 2. There are several things coming to me mind:
#
# - If doing logistic regression with L2/L1 penalty, you can both try standardize it or not. It would be better if you standardize it (may be use scikit learn processing.standardize(with_mean = True,with_std = True)). Then find the predictors with highest postive coefficients and corresponding to the variable names!
# - If do decision trees to find important variable, try visualize the top variables!

# %%
#predictors 
x = merged.drop("CMI:75 F3a) Epilepsy: Ever suffered",1,inplace = False).values

#labels for all predictors
labels = merged.drop("CMI:75 F3a) Epilepsy: Ever suffered",1,inplace = False).columns

#classification 
y = merged["CMI:75 F3a) Epilepsy: Ever suffered"].values
y[y != 1] = 0

# %%
print "Number of epilepsy patients: ", y.sum()
# Out:
# Number of epilepsy patients:  141.0

# %%
# x = merged.drop("CMI:75 F3a) Epilepsy: Ever suffered",1,inplace = False)
# x.to_csv('x_cleaned_data.csv')
# np.savetxt("y_cleaned_data.csv", y, delimiter=",")
